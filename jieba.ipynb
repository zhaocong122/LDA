# %%
import jieba
import re
import csv
 
# 创建停用词列表
def stopwordslist():
    stopwords = [line.strip() for line in open('C:/Users/ASUS/Desktop/数学建模/数据/MU5735/StopWords.txt',encoding='UTF-8').readlines()]
    return stopwords
 
def processing(text):
    """
    数据清洗, 可以根据自己的需求进行重载
    """
    text = re.sub("@.+?( |$)", "", text)           # 去除 @xxx (用户名)
    text = re.sub("【.+?】", "", text)             # 去除 【xx】 (里面的内容通常都不是用户自己写的)
    text = re.sub(".*?:", "", text)                #去除微博用户的名字
    text = re.sub("#.*#", "", text)                #去除话题引用
    text = re.sub("\n","",text)
    return text
 
# 对句子进行中文分词
def seg_depart(sentence):
    jieba.load_userdict('C:/Users/ASUS/Desktop/数学建模/数据/MU5735/保留词.txt')
    sentence_depart = jieba.cut(sentence.strip())
    print(sentence_depart)
    stopwords = stopwordslist()        # 创建一个停用词列表
    outstr = ''        # 输出结果为outstr
    for word in sentence_depart:          # 去停用词
        if word not in stopwords:
            if word != '\t':
                outstr += word
                outstr += " "
    return outstr
 
# 给出文档路径
filename = "C:/Users/ASUS/Desktop/数学建模/数据/MU5735/mu5735词频.txt"   #原文档路径
outputs = open("C:/Users/ASUS/Desktop/数学建模/数据/MU5735/output.txt", 'w', encoding='UTF-8')  #输出文档路径
with open(filename, 'r', encoding='utf-8-sig') as csvfile:
    reader = csv.reader(csvfile,delimiter=',',quotechar='"',doublequote=False)
    for line in reader:
        print(line[0])     #微博在文档的第一列
        line = processing(line[0])
        line_seg = seg_depart(line)
        outputs.write(line_seg + '\n')
outputs.close()
print("分词成功！！！")
# Out:
# #mu5735##海航重整舞弊终生蒙羞##海航开创中国企业逃废债之先河##全国两会##海航集团更多高管被带走#  【做一个体面的个体债权人】                ——借江歌事件阐述海南省海航集团和全国六万多普通群众之间的故事  江歌妈妈和刘鑫的故事就这样结束了吗？远远没有，江歌妈妈决定把近70万的赔偿款捐给	#mu5735##海航重整舞弊终生蒙羞##海航开创中国企业逃废债之先河##全国两会##海航集团更多高管被带走# 【做一个体面的个体债权人】 ——借江歌事件阐述海南省海航集团和全国六万多普通群众之间的故事 江歌妈妈和刘鑫的故事就这样结束了吗？
# <generator object Tokenizer.cut at 0x00000255AD083900>
# 在末法时代，地藏法门对娑婆世界的众生摄受力最大，因缘最深。众生都怕地狱，怕三途苦难。当我们闻到地藏菩萨名字，念地藏菩萨圣号，闻到地藏三经任何一经名，可以免除地狱的痛苦，不再流转三途。 #祈福MU5735全员平安#	#祈福MU5735全员平安#
# <generator object Tokenizer.cut at 0x00000255AD083900>
# 2022.03.21 #20220321MU5735#mu5735感人的瞬间	2022.03.21 #20220321MU5735#mu5735感人的瞬间
# <generator object Tokenizer.cut at 0x00000255AD083900>
# 今天是农历二月十九 观世音菩萨圣诞日 愿疫除人安 愿众生平安吉祥 愿国泰民安 为#mu5735#  航班祈福 #20220321MU5735#  🙏🙏🙏 http://t.cn/A666tQ54	今天是农历二月十九 观世音菩萨圣诞日 愿疫除人安 愿众生平安吉祥 愿国泰民安 🙏🙏🙏 张俊扬导演的微博视频
# <generator object Tokenizer.cut at 0x00000255AD083900>
# 发广大慈心，不为自己现实利益，而愿一切众生都成佛，这个心就与地藏菩萨相合了。谁能这么做，谁就是地藏菩萨，一念心做一念是，念念心做念念是。 #祈福MU5735全员平安#	#祈福MU5735全员平安#
# ...
